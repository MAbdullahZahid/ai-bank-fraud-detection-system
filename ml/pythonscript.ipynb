# %%
import pandas as pd

train = pd.read_csv("dataset/raw/train.csv")
print(train.shape)
print(train.columns)

val = pd.read_csv("dataset/raw/validation.csv")
print(val.shape)
# Out:
# (5090096, 11)
# Index(['step', 'type', 'amount', 'nameOrig', 'oldbalanceOrg', 'newbalanceOrig',
#        'nameDest', 'oldbalanceDest', 'newbalanceDest', 'isFlaggedFraud',
#        'isFraud'],
#       dtype='object')
# (1272524, 11)
